# %%
import pandas as pd

# %%
dict_data={"Firstname":["Imma","Vini","Celsia","Stancia","Nabilatou","Elohim","Gloria","Consolas","Carine"],
           "Age":[23,22,20,23,22,18,22,23,22],
           "Mat":["23WIADA0001","23WIADA0002","23WIADA0003","23WIADA0004","23WIADA0005","23WIADA0006","23WIADA0007","23WIADA0008","23WIADA0009"]}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    Firstname  Age          Mat
# 0       Imma   23  23WIADA0001
# 1       Vini   22  23WIADA0002
# 2     Celsia   20  23WIADA0003
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 5     Elohim   18  23WIADA0006
# 6     Gloria   22  23WIADA0007
# 7   Consolas   23  23WIADA0008
# 8     Carine   22  23WIADA0009

# %%
df["Firstname"]
# Out:
# 0         Imma
# 1         Vini
# 2       Celsia
# 3      Stancia
# 4    Nabilatou
# 5       Elohim
# 6       Gloria
# 7     Consolas
# 8       Carine
# Name: Firstname, dtype: object

# %%
df[["Firstname", "Mat"]]
# Out:
#    Firstname          Mat
# 0       Imma  23WIADA0001
# 1       Vini  23WIADA0002
# 2     Celsia  23WIADA0003
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007
# 7   Consolas  23WIADA0008
# 8     Carine  23WIADA0009

# %%
df.loc[1]
# Out:
# Firstname           Vini
# Age                   22
# Mat          23WIADA0002
# Name: 1, dtype: object

# %%
df.loc[1, ["Firstname", "Age"]]
# Out:
# Firstname    Vini
# Age            22
# Name: 1, dtype: object

# %%
df.loc[1, "Mat"]
# Out:
# '23WIADA0002'

# %%
df.loc[:, "Mat"]
# Out:
# 0    23WIADA0001
# 1    23WIADA0002
# 2    23WIADA0003
# 3    23WIADA0004
# 4    23WIADA0005
# 5    23WIADA0006
# 6    23WIADA0007
# 7    23WIADA0008
# 8    23WIADA0009
# Name: Mat, dtype: object

# %%
df.loc[0:4, "Mat"]
# Out:
# 0    23WIADA0001
# 1    23WIADA0002
# 2    23WIADA0003
# 3    23WIADA0004
# 4    23WIADA0005
# Name: Mat, dtype: object

# %%
df.loc[3:, ["Firstname", "Mat"]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007
# 7   Consolas  23WIADA0008
# 8     Carine  23WIADA0009

# %%
df.loc[3:6, ["Firstname", "Mat"]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007

# %%
df.iloc[:, [0]]
# Out:
#    Firstname
# 0       Imma
# 1       Vini
# 2     Celsia
# 3    Stancia
# 4  Nabilatou
# 5     Elohim
# 6     Gloria
# 7   Consolas
# 8     Carine

# %%
df.iloc[1, 0]
# Out:
# 'Vini'

# %%
df.iloc[3:7, [0, 2]]
# Out:
#    Firstname          Mat
# 3    Stancia  23WIADA0004
# 4  Nabilatou  23WIADA0005
# 5     Elohim  23WIADA0006
# 6     Gloria  23WIADA0007

# %%
df.iloc[3:7, :2]
# Out:
#    Firstname  Age
# 3    Stancia   23
# 4  Nabilatou   22
# 5     Elohim   18
# 6     Gloria   22

# %%
df.sort_values("Firstname")
# Out:
#    Firstname  Age          Mat
# 8     Carine   22  23WIADA0009
# 2     Celsia   20  23WIADA0003
# 7   Consolas   23  23WIADA0008
# 5     Elohim   18  23WIADA0006
# 6     Gloria   22  23WIADA0007
# 0       Imma   23  23WIADA0001
# 4  Nabilatou   22  23WIADA0005
# 3    Stancia   23  23WIADA0004
# 1       Vini   22  23WIADA0002

# %%
df.sort_values("Firstname", ascending=False)
# Out:
#    Firstname  Age          Mat
# 1       Vini   22  23WIADA0002
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 0       Imma   23  23WIADA0001
# 6     Gloria   22  23WIADA0007
# 5     Elohim   18  23WIADA0006
# 7   Consolas   23  23WIADA0008
# 2     Celsia   20  23WIADA0003
# 8     Carine   22  23WIADA0009

# %%
df.sort_values(["Firstname", "Mat"], ascending=False)
# Out:
#    Firstname  Age          Mat
# 1       Vini   22  23WIADA0002
# 3    Stancia   23  23WIADA0004
# 4  Nabilatou   22  23WIADA0005
# 0       Imma   23  23WIADA0001
# 6     Gloria   22  23WIADA0007
# 5     Elohim   18  23WIADA0006
# 7   Consolas   23  23WIADA0008
# 2     Celsia   20  23WIADA0003
# 8     Carine   22  23WIADA0009

# %%
df.iloc[0,0] = "Immaculée Conception"
df
# Out:
#               Firstname  Age          Mat
# 0  Immaculée Conception   23  23WIADA0001
# 1                  Vini   22  23WIADA0002
# 2                Celsia   20  23WIADA0003
# 3               Stancia   23  23WIADA0004
# 4             Nabilatou   22  23WIADA0005
# 5                Elohim   18  23WIADA0006
# 6                Gloria   22  23WIADA0007
# 7              Consolas   23  23WIADA0008
# 8                Carine   22  23WIADA0009

# %%
df.iloc[2,1] = 21
df
# Out:
#               Firstname  Age          Mat
# 0  Immaculée Conception   23  23WIADA0001
# 1                  Vini   22  23WIADA0002
# 2                Celsia   21  23WIADA0003
# 3               Stancia   23  23WIADA0004
# 4             Nabilatou   22  23WIADA0005
# 5                Elohim   18  23WIADA0006
# 6                Gloria   22  23WIADA0007
# 7              Consolas   23  23WIADA0008
# 8                Carine   22  23WIADA0009

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'Firstname', 'Age', 'Mat'], dtype='object')

# %%
df.drop("index", axis=1, inplace=True)
df
# Out:
#    level_0             Firstname  Age          Mat
# 0        0  Immaculée Conception   23  23WIADA0001
# 1        1                  Vini   22  23WIADA0002
# 2        2               Stancia   23  23WIADA0004
# 3        3             Nabilatou   22  23WIADA0005
# 4        4                Elohim   18  23WIADA0006
# 5        5                Gloria   22  23WIADA0007
# 6        6              Consolas   23  23WIADA0008
# 7        7                Carine   22  23WIADA0009

# %%
df.drop("level_0", axis=1, inplace=True)
df
# Out:
#               Firstname  Age          Mat
# 0  Immaculée Conception   23  23WIADA0001
# 1                  Vini   22  23WIADA0002
# 2               Stancia   23  23WIADA0004
# 3             Nabilatou   22  23WIADA0005
# 4                Elohim   18  23WIADA0006
# 5                Gloria   22  23WIADA0007
# 6              Consolas   23  23WIADA0008
# 7                Carine   22  23WIADA0009

# %%
df.set_index("Mat", inplace=True)

# %% [markdown]
# df
